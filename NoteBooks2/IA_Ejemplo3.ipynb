# %% [markdown]
# ## **Aprendizaje supervisado**. *Calculando el precio de un vehículo con validación cruzada*

# %%
import sklearn
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
import matplotlib.pyplot as plt

# %% [markdown]
# *   Se cargan los datos del archivo CSV a un **dataframe**. Un dataframe es una estructura de datos con filas y columnas

# %%
dataFrame1=pd.read_csv('car prices dataset.csv')
dataFrame1
# Out:
#                                   name  year  km_driven  fuel  seller_type  \
# 0                        Maruti 800 AC  2007      70000     0            0
# 1             Maruti Wagon R LXI Minor  2007      50000     0            0
# 2                 Hyundai Verna 1.6 SX  2012     100000     1            0
# 3               Datsun RediGO T Option  2017      46000     0            0
# 4                Honda Amaze VX i-DTEC  2014     141000     1            0
# ...                                ...   ...        ...   ...          ...
# 4335    Hyundai i20 Magna 1.4 CRDi (1)  2014      80000     1            0
# 4336        Hyundai i20 Magna 1.4 CRDi  2014      80000     1            0
# 4337               Maruti 800 AC BSIII  2009      83000     0            0
# 4338  Hyundai Creta 1.6 CRDi SX Option  2016      90000     1            0
# 4339                  Renault KWID RXT  2016      40000     0            0
#
#       transmission  owner  selling_price
# 0                0      1           6000
# 1                0      1          13500
# 2                0      1          60000
# 3                0      1          25000
# 4                0      2          45000
# ...            ...    ...            ...
# 4335             0      2          40999
# 4336             0      2          40999
# 4337             0      2          11000
# 4338             0      1          86500
# 4339             0      1          22500
#
# [4340 rows x 8 columns]

# %%
dataFrame1.describe()
# Out:
#               year      km_driven         fuel  seller_type  transmission  \
# count  4340.000000    4340.000000  4340.000000  4340.000000   4340.000000
# mean   2013.090783   66215.777419     0.531336     0.276037      0.103226
# std       4.215344   46644.102194     0.549621     0.496892      0.304289
# min    1992.000000       1.000000     0.000000     0.000000      0.000000
# 25%    2011.000000   35000.000000     0.000000     0.000000      0.000000
# 50%    2014.000000   60000.000000     1.000000     0.000000      0.000000
# 75%    2016.000000   90000.000000     1.000000     1.000000      0.000000
# max    2020.000000  806599.000000     4.000000     2.000000      1.000000
#
#              owner  selling_price
# count  4340.000000    4340.000000
# mean      1.454839   50412.695853
# std       0.707212   57854.880395
# min       1.000000    2000.000000
# 25%       1.000000   20874.750000
# 50%       1.000000   35000.000000
# 75%       2.000000   60000.000000
# max       4.000000  890000.000000

# %% [markdown]
# *   Se usa *info()* para conocer las columnas del dataframe, la cantidad de datos nulos, el tipo de datos de cada columna, y la cantidad de filas

# %%
dataFrame1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   km_driven      4340 non-null   int64
#  3   fuel           4340 non-null   int64
#  4   seller_type    4340 non-null   int64
#  5   transmission   4340 non-null   int64
#  6   owner          4340 non-null   int64
#  7   selling_price  4340 non-null   int64
# dtypes: int64(7), object(1)
# memory usage: 271.4+ KB

# %% [markdown]
# *   Se seleccionan las **variables independientes**

# %%
X = dataFrame1[["year", "km_driven", "fuel", "transmission", "owner"]]
X
# Out:
#       year  km_driven  fuel  transmission  owner
# 0     2007      70000     0             0      1
# 1     2007      50000     0             0      1
# 2     2012     100000     1             0      1
# 3     2017      46000     0             0      1
# 4     2014     141000     1             0      2
# ...    ...        ...   ...           ...    ...
# 4335  2014      80000     1             0      2
# 4336  2014      80000     1             0      2
# 4337  2009      83000     0             0      2
# 4338  2016      90000     1             0      1
# 4339  2016      40000     0             0      1
#
# [4340 rows x 5 columns]

# %% [markdown]
# *   Se selecciona la **variable dependiente**

# %%
Y = dataFrame1[["selling_price"]]
Y
# Out:
#       selling_price
# 0              6000
# 1             13500
# 2             60000
# 3             25000
# 4             45000
# ...             ...
# 4335          40999
# 4336          40999
# 4337          11000
# 4338          86500
# 4339          22500
#
# [4340 rows x 1 columns]

# %% [markdown]
# *   Se separa el conjunto de datos en **80% para el entrenamiento** y **20% para pruebas**. La separación se hace indicando el dataframe que tiene las variables independientes (X) y el dataframe con la variable dependiente (Y)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %% [markdown]
# *   Se entrena un modelo de regresión

# %%
modelo1 = LinearRegression()
modelo1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# *   Una vez entrenado el modelo, se usa para hacer las predicciones sobre el conjunto de prueba. Al modelo solo se le pasan los valores de X, es decir, los variables independiente en el conjunto de prueba

# %%
predicciones = modelo1.predict(X_test)
predicciones
# Out:
# array([[ 1.39809721e+05],
#        [-1.95487296e+01],
#        [ 3.75177272e+04],
#        [ 4.35036949e+04],
#        [ 5.07896792e+04],
#        [ 4.26971999e+04],
#        [ 4.77552464e+04],
#        [ 1.42410021e+05],
#        [ 7.92398565e+04],
#        [ 6.36656664e+04],
#        [ 4.86253223e+04],
#        [ 5.28625188e+04],
#        [ 5.39848390e+04],
#        [ 6.50764119e+03],
#        [ 5.25026221e+04],
#        [ 1.58541754e+05],
#        [ 1.39011887e+05],
#        [ 2.40714423e+04],
#        [ 6.12844403e+04],
#        [ 2.47900043e+04],
#        [-1.48864844e+04],
#        [ 1.82623768e+04],
#        [ 1.00804683e+04],
#        [ 5.25026221e+04],
#        [-4.01053823e+03],
#        [ 6.12844403e+04],
#        [ 4.38781865e+04],
#        [-6.50241131e+03],
#        [ 3.65922022e+04],
#        [ 3.89673812e+03],
#        [ 1.42724951e+05],
#        [ 6.07692939e+04],
#        [ 5.17152978e+04],
#        [ 6.32421367e+04],
#        [ 1.59814228e+05],
#        [ 2.91700531e+04],
#        [ 6.00866837e+04],
#        [ 1.13446885e+05],
#        [ 5.39389766e+04],
#        [ 5.25341151e+04],
#        [ 5.21089599e+04],
#        [ 4.00542999e+04],
#        [ 5.31874369e+04],
#        [ 5.47263010e+04],
#        [ 4.71381196e+04],
#        [ 3.30492426e+04],
#        [ 4.16730956e+04],
#        [ 6.68936962e+04],
#        [ 7.03004911e+04],
#        [ 3.98820029e+04],
#        [ 4.30606675e+04],
#        [ 5.90133244e+04],
#        [ 4.28333647e+04],
#        [ 1.33164357e+04],
#        [-2.13765769e+04],
#        [-1.51928467e+04],
#        [ 2.34424987e+04],
#        [ 1.93326340e+04],
#        [ 5.32028707e+04],
#        [ 1.39396888e+05],
#        [-1.86346238e+03],
#        [ 8.86961427e+03],
#        [ 3.34429048e+04],
#        [ 2.44226775e+04],
#        [ 5.32090846e+04],
#        [ 6.12844403e+04],
#        [ 5.97579516e+04],
#        [ 7.13941778e+04],
#        [ 6.40593286e+04],
#        [ 2.37952176e+03],
#        [-3.91907310e+03],
#        [ 5.27281226e+04],
#        [ 7.37860183e+04],
#        [ 1.59105636e+05],
#        [ 5.71691359e+04],
#        [ 1.25316485e+05],
#        [ 1.60152685e+04],
#        [ 4.71763814e+04],
#        [ 5.40772708e+04],
#        [ 4.16473924e+04],
#        [ 5.71691359e+04],
#        [ 4.68406248e+03],
#        [ 4.02457976e+04],
#        [ 7.72715456e+04],
#        [ 7.53606670e+04],
#        [ 6.03376040e+04],
#        [ 2.78783372e+04],
#        [ 3.92904051e+04],
#        [ 3.96840673e+04],
#        [ 4.07800228e+04],
#        [ 4.73637137e+04],
#        [ 5.10279320e+04],
#        [ 5.81819607e+04],
#        [ 8.19945723e+03],
#        [ 6.49253853e+04],
#        [ 4.85660003e+04],
#        [ 1.48044144e+04],
#        [ 3.79412568e+04],
#        [ 4.23822702e+04],
#        [ 5.11259090e+04],
#        [ 6.60276394e+04],
#        [ 1.05039980e+04],
#        [ 5.55944872e+04],
#        [ 7.44670539e+04],
#        [ 4.06693272e+04],
#        [ 4.94107570e+04],
#        [ 6.05738013e+04],
#        [ 3.61985400e+04],
#        [ 2.96444836e+04],
#        [ 4.69679221e+04],
#        [ 3.16107586e+04],
#        [ 1.49724825e+04],
#        [ 7.92398565e+04],
#        [ 1.59088393e+05],
#        [ 5.32211730e+04],
#        [ 4.04713916e+04],
#        [ 1.45106094e+05],
#        [ 4.46059490e+04],
#        [ 7.03004911e+04],
#        [ 3.19575917e+04],
#        [ 4.16331139e+04],
#        [ 2.96211477e+04],
#        [ 1.42132328e+05],
#        [ 5.17152978e+04],
#        [ 7.71849522e+03],
#        [ 1.83198092e+04],
#        [ 1.68438663e+05],
#        [ 5.12407737e+04],
#        [ 5.25729774e+04],
#        [ 2.02008202e+04],
#        [ 6.95131667e+04],
#        [ 1.97332926e+04],
#        [ 5.22485489e+04],
#        [ 4.85239899e+04],
#        [ 8.25688958e+03],
#        [ 1.66642986e+04],
#        [ 6.32145718e+04],
#        [ 4.33950950e+04],
#        [-1.31946683e+04],
#        [ 1.54202925e+05],
#        [ 5.35261438e+04],
#        [ 7.45733427e+04],
#        [ 5.11534739e+04],
#        [ 4.26077706e+04],
#        [ 2.29863230e+04],
#        [ 2.20415337e+04],
#        [ 3.26257129e+04],
#        [ 2.76528368e+04],
#        [ 5.41008906e+04],
#        [ 4.91575981e+04],
#        [ 5.05108817e+04],
#        [ 3.63713540e+04],
#        [ 3.82116663e+04],
#        [ 4.08650538e+04],
#        [-1.86346238e+03],
#        [ 4.22822377e+04],
#        [ 2.99535560e+04],
#        [ 5.21089599e+04],
#        [ 3.69304679e+04],
#        [ 5.28941548e+04],
#        [ 1.89325339e+04],
#        [ 4.09811077e+04],
#        [ 5.76808968e+04],
#        [ 4.12902090e+04],
#        [ 5.70308417e+04],
#        [ 6.01801391e+04],
#        [ 4.96661250e+04],
#        [ 1.39810627e+05],
#        [ 7.34708005e+02],
#        [ 1.57790711e+04],
#        [ 5.86629227e+04],
#        [-2.06381175e+04],
#        [ 1.39596577e+04],
#        [ 1.42488753e+05],
#        [ 7.02430587e+04],
#        [ 8.98678159e+03],
#        [ 5.04752196e+04],
#        [ 5.44709330e+04],
#        [ 1.26661632e+05],
#        [ 1.18456495e+04],
#        [ 6.49444005e+02],
#        [ 4.03840918e+04],
#        [ 6.63638693e+04],
#        [ 6.48466529e+04],
#        [ 4.12587160e+04],
#        [ 4.15140839e+04],
#        [ 1.67651339e+05],
#        [ 5.20280981e+04],
#        [ 6.68224086e+03],
#        [ 4.54720058e+04],
#        [ 6.18356497e+04],
#        [ 5.58199877e+04],
#        [ 4.63188920e+04],
#        [ 1.28454744e+03],
#        [ 5.31854649e+04],
#        [ 3.23107832e+04],
#        [ 1.11827224e+04],
#        [ 1.39596577e+04],
#        [ 4.51379054e+04],
#        [ 1.10886976e+05],
#        [ 3.15234588e+04],
#        [-1.95783002e+04],
#        [ 8.50581957e+03],
#        [ 2.43055101e+04],
#        [ 5.13982386e+04],
#        [ 1.11123539e+03],
#        [ 4.38781865e+04],
#        [ 4.91724303e+04],
#        [ 4.90371316e+04],
#        [ 7.53606670e+04],
#        [ 6.60489395e+04],
#        [ 1.45412457e+05],
#        [ 5.97864769e+04],
#        [ 6.71511936e+04],
#        [ 1.33155726e+05],
#        [ 8.67388768e+03],
#        [-1.95487296e+01],
#        [ 5.28962843e+04],
#        [ 6.01801391e+04],
#        [ 1.38168662e+05],
#        [ 3.41429293e+04],
#        [ 1.75259533e+04],
#        [ 2.46931107e+04],
#        [ 6.51615827e+04],
#        [ 1.44406197e+04],
#        [ 4.83978386e+04],
#        [-3.07431640e+03],
#        [ 7.82609409e+04],
#        [ 1.93284987e+04],
#        [ 4.72742844e+04],
#        [ 6.58222410e+04],
#        [-2.84881594e+03],
#        [ 7.06941532e+04],
#        [ 6.09674635e+04],
#        [ 4.62614596e+04],
#        [ 4.39569189e+04],
#        [ 1.70515228e+04],
#        [ 6.69937288e+04],
#        [ 8.34339757e+04],
#        [ 6.55765449e+04],
#        [ 2.55163642e+04],
#        [ 5.62435173e+04],
#        [ 5.63818116e+04],
#        [ 4.69679221e+04],
#        [ 4.87213358e+04],
#        [ 8.33562201e+03],
#        [ 7.51116434e+04],
#        [ 1.84112740e+03],
#        [ 3.87285812e+04],
#        [ 6.24846798e+04],
#        [ 6.46419486e+04],
#        [ 5.25026221e+04],
#        [ 5.70308417e+04],
#        [ 8.02928854e+03],
#        [ 1.12634907e+04],
#        [ 3.02637398e+04],
#        [ 3.06638400e+04],
#        [ 4.84552710e+04],
#        [ 5.63711147e+04],
#        [ 4.87915008e+04],
#        [ 4.55315676e+04],
#        [-1.36756304e+04],
#        [ 5.03975493e+04],
#        [ 7.72715456e+04],
#        [ 6.33294365e+04],
#        [ 7.42584129e+04],
#        [ 2.17754690e+04],
#        [-3.46246009e+02],
#        [ 3.48493917e+04],
#        [ 5.94916240e+04],
#        [ 2.60483206e+04],
#        [ 5.55515501e+04],
#        [ 2.24244991e+04],
#        [ 5.20280981e+04],
#        [ 1.26661632e+05],
#        [-1.04563398e+04],
#        [ 3.69793328e+04],
#        [ 4.96086926e+04],
#        [ 7.37751496e+04],
#        [ 3.09426374e+04],
#        [ 1.39750397e+05],
#        [ 5.79564603e+04],
#        [ 1.01310577e+05],
#        [ 1.68281198e+05],
#        [ 1.77762768e+04],
#        [ 3.24768154e+04],
#        [ 4.92724628e+04],
#        [ 6.68224086e+03],
#        [ 2.60547585e+04],
#        [ 2.77315692e+04],
#        [-2.13765769e+04],
#        [ 1.15670657e+05],
#        [ 8.38865225e+03],
#        [ 1.90591999e+04],
#        [ 4.12587160e+04],
#        [ 3.60602458e+04],
#        [ 5.77989954e+04],
#        [ 7.33923561e+04],
#        [ 2.78103016e+04],
#        [ 2.45035393e+04],
#        [ 1.46761605e+05],
#        [ 2.09072827e+04],
#        [ 4.51379054e+04],
#        [ 3.28512134e+04],
#        [ 5.81245284e+04],
#        [-3.32977796e+03],
#        [ 3.93178763e+04],
#        [ 3.76998245e+04],
#        [ 1.44318770e+05],
#        [ 1.47706394e+05],
#        [ 4.45186492e+04],
#        [ 8.32516879e+04],
#        [ 1.97198582e+04],
#        [ 4.48510832e+04],
#        [ 5.06683466e+04],
#        [ 1.42132328e+05],
#        [ 1.38505082e+05],
#        [ 5.35154469e+04],
#        [ 6.74661234e+04],
#        [ 6.82448803e+04],
#        [ 4.24224768e+04],
#        [ 4.10331219e+04],
#        [ 3.48493917e+04],
#        [ 6.05908075e+04],
#        [ 1.74153175e+04],
#        [ 3.13745613e+04],
#        [ 5.10759215e+03],
#        [ 5.50125432e+03],
#        [ 1.64402009e+05],
#        [ 6.42955259e+04],
#        [ 3.81668509e+04],
#        [-6.70457584e+03],
#        [ 5.59072875e+04],
#        [ 4.43505811e+04],
#        [ 5.35588965e+04],
#        [ 4.67920375e+04],
#        [-3.02851435e+04],
#        [ 2.73019771e+04],
#        [ 1.32197510e+05],
#        [ 1.75026173e+04],
#        [ 4.29897660e+04],
#        [ 4.75605448e+04],
#        [ 7.26050318e+04],
#        [ 5.23643279e+04],
#        [ 3.60602458e+04],
#        [ 1.03037350e+03],
#        [ 6.12844403e+04],
#        [ 1.71089552e+04],
#        [-7.07259948e+03],
#        [ 4.39569189e+04],
#        [ 5.05130111e+04],
#        [ 1.19859580e+05],
#        [ 7.49670049e+04],
#        [ 1.47293675e+05],
#        [ 4.98280390e+04],
#        [ 5.89491650e+03],
#        [ 1.73007474e+04],
#        [ 4.51379054e+04],
#        [ 3.64240405e+04],
#        [ 3.85562841e+04],
#        [ 2.55802644e+04],
#        [ 4.69679221e+04],
#        [ 1.21869798e+04],
#        [ 7.49123646e+04],
#        [ 5.56710902e+04],
#        [ 4.49697437e+04],
#        [ 6.22293119e+04],
#        [ 1.36641253e+05],
#        [ 8.98678159e+03],
#        [ 5.13216356e+04],
#        [ 3.89673812e+03],
#        [ 3.79412568e+04],
#        [ 2.12136451e+04],
#        [ 1.42132328e+05],
#        [ 1.46919070e+05],
#        [ 5.32899465e+04],
#        [ 6.87258423e+04],
#        [ 4.46805874e+04],
#        [ 1.60286622e+05],
#        [ 7.06068534e+04],
#        [ 5.81139252e+04],
#        [ 5.45688361e+04],
#        [ 1.37107277e+04],
#        [ 8.13762355e+04],
#        [ 3.68684743e+04],
#        [ 6.64527946e+04],
#        [ 4.24397025e+04],
#        [ 5.00597872e+04],
#        [ 7.76652078e+04],
#        [ 5.02179220e+04],
#        [ 2.93781901e+04],
#        [ 7.37860183e+04],
#        [ 3.08935993e+04],
#        [-3.13174875e+03],
#        [-2.02949464e+03],
#        [ 2.57779449e+04],
#        [ 4.65469011e+04],
#        [ 1.89855975e+03],
#        [ 1.51171332e+05],
#        [ 3.15234588e+04],
#        [ 5.20982631e+04],
#        [ 3.53294343e+03],
#        [ 3.36982727e+04],
#        [ 3.63453080e+04],
#        [ 2.78326253e+04],
#        [ 4.49123114e+04],
#        [ 1.67651339e+05],
#        [ 4.61647339e+04],
#        [ 1.98944579e+04],
#        [ 1.20477674e+05],
#        [ 2.37736473e+04],
#        [ 1.37107277e+04],
#        [ 3.06446693e+04],
#        [ 5.67754737e+04],
#        [ 4.99042483e+03],
#        [ 3.34130373e+04],
#        [ 7.06941532e+04],
#        [ 1.37428577e+05],
#        [ 3.88699739e+04],
#        [ 5.75627981e+04],
#        [ 5.93928148e+04],
#        [ 7.35432862e+04],
#        [ 5.10381988e+04],
#        [ 7.49670049e+04],
#        [ 2.42480778e+04],
#        [ 5.48071629e+04],
#        [ 4.58744110e+04],
#        [ 6.87258423e+04],
#        [ 1.83198092e+04],
#        [ 1.39507192e+05],
#        [ 1.42822854e+05],
#        [ 3.50518021e+04],
#        [ 1.55211860e+04],
#        [ 5.85149481e+04],
#        [ 1.52285790e+05],
#        [ 3.51643215e+04],
#        [ 3.88699739e+04],
#        [ 5.32899465e+04],
#        [ 4.60059981e+04],
#        [-3.86164075e+03],
#        [ 2.30662472e+04],
#        [ 8.81983925e+04],
#        [ 3.18383886e+04],
#        [ 1.39967186e+05],
#        [ 4.10757221e+04],
#        [ 5.32899465e+04],
#        [ 5.11534739e+04],
#        [ 4.25098676e+04],
#        [ 1.27759320e+05],
#        [ 5.30729198e+04],
#        [ 6.09100311e+04],
#        [ 1.39396888e+05],
#        [ 3.47813562e+04],
#        [-7.57479792e+03],
#        [ 3.28512134e+04],
#        [ 5.66276893e+04],
#        [ 5.75627981e+04],
#        [ 4.78275409e+04],
#        [ 4.26077706e+04],
#        [ 5.04555788e+04],
#        [ 1.34417481e+05],
#        [ 3.40896323e+04],
#        [ 1.61727333e+04],
#        [ 7.44946102e+04],
#        [ 5.39389766e+04],
#        [ 4.70189165e+04],
#        [ 3.83930578e+03],
#        [ 4.22886937e+04],
#        [ 1.27227364e+05],
#        [ 3.72347944e+04],
#        [ 5.84883231e+04],
#        [ 5.17152978e+04],
#        [ 6.37164957e+03],
#        [ 6.40593286e+04],
#        [ 3.69858644e+04],
#        [ 5.42453389e+04],
#        [ 4.55315676e+04],
#        [ 7.40132401e+04],
#        [ 2.33692883e+04],
#        [ 1.42132328e+05],
#        [ 4.94107570e+04],
#        [ 4.66252543e+04],
#        [ 3.94010408e+04],
#        [ 1.09005965e+05],
#        [ 5.47837333e+04],
#        [ 1.59892960e+05],
#        [ 4.18204463e+04],
#        [ 4.32026779e+03],
#        [ 9.99960640e+03],
#        [ 4.68406248e+03],
#        [ 1.63063558e+05],
#        [ 6.22293119e+04],
#        [ 1.71089552e+04],
#        [ 5.74053332e+04],
#        [ 7.48572518e+04],
#        [ 2.83018669e+04],
#        [-1.65928958e+04],
#        [ 3.10941377e+03],
#        [ 3.99968676e+04],
#        [ 3.41429293e+04],
#        [ 4.69679221e+04],
#        [ 1.71089552e+04],
#        [ 1.43669740e+05],
#        [ 6.46419486e+04],
#        [ 1.61231412e+05],
#        [ 3.63431786e+04],
#        [ 4.77136232e+03],
#        [ 7.82456983e+04],
#        [ 5.15557034e+04],
#        [ 2.54678906e+04],
#        [ 2.29863230e+04],
#        [ 5.25026221e+04],
#        [ 4.49804406e+04],
#        [ 4.69679221e+04],
#        [ 3.38365669e+04],
#        [ 1.22069285e+05],
#        [ 5.70882740e+04],
#        [ 4.70487840e+04],
#        [ 1.39011887e+05],
#        [ 7.45733427e+04],
#        [ 3.24768154e+04],
#        [ 1.27851091e+04],
#        [ 7.01369638e+04],
#        [ 1.61231412e+05],
#        [ 1.74153175e+04],
#        [ 5.10524461e+03],
#        [ 1.10932931e+04],
#        [ 1.17423807e+05],
#        [ 4.18204463e+04],
#        [ 9.35057628e+03],
#        [ 4.12902090e+04],
#        [ 8.14350100e+04],
#        [ 5.32899465e+04],
#        [ 3.20638890e+04],
#        [ 6.87258423e+04],
#        [ 3.50175535e+04],
#        [ 5.42326063e+04],
#        [ 4.78361083e+04],
#        [ 1.05315628e+04],
#        [ 4.14566516e+04],
#        [ 6.91982370e+04],
#        [ 4.51379054e+04],
#        [ 3.08000047e+04],
#        [ 3.72562846e+04],
#        [ 2.72293071e+04],
#        [ 3.34130373e+04],
#        [ 8.86451684e+04],
#        [ 4.61676069e+04],
#        [ 1.56006449e+05],
#        [ 5.47512205e+04],
#        [ 5.80711698e+04],
#        [ 2.01572706e+03],
#        [ 1.39011887e+05],
#        [-8.86942991e+02],
#        [ 2.05071826e+04],
#        [ 4.51379054e+04],
#        [ 1.58541754e+05],
#        [ 5.80036997e+04],
#        [ 4.30887326e+04],
#        [ 3.96840673e+04],
#        [ 1.41759773e+03],
#        [ 4.14161809e+04],
#        [ 1.27632654e+05],
#        [ 4.38186246e+04],
#        [ 1.05425964e+05],
#        [-1.65928958e+04],
#        [ 1.40439463e+05],
#        [ 3.74532588e+04],
#        [ 4.65469011e+04],
#        [ 5.42347357e+04],
#        [ 8.01059133e+04],
#        [ 2.48673340e+04],
#        [ 5.31750818e+04],
#        [ 5.01800116e+04],
#        [ 5.10620087e+04],
#        [ 7.15995763e+04],
#        [ 1.76927102e+04],
#        [ 4.87915008e+04],
#        [ 3.59503074e+04],
#        [ 4.38781865e+04],
#        [ 3.61198076e+04],
#        [ 6.51530153e+04],
#        [ 3.10941377e+03],
#        [ 4.66252543e+04],
#        [ 3.89647785e+04],
#        [ 5.79564603e+04],
#        [ 1.98157255e+04],
#        [ 2.76666937e+04],
#        [ 6.19122527e+04],
#        [ 1.39011887e+05],
#        [ 4.18778786e+04],
#        [ 6.82448803e+04],
#        [ 4.08650538e+04],
#        [ 5.75627981e+04],
#        [ 5.33686789e+04],
#        [ 3.10941377e+03],
#        [ 1.50559933e+05],
#        [ 5.27281226e+04],
#        [ 4.23822702e+04],
#        [ 4.41824193e+04],
#        [ 5.63009497e+04],
#        [ 5.31516522e+04],
#        [ 9.26500091e+04],
#        [ 1.83198092e+04],
#        [ 7.49123646e+04],
#        [ 1.46446675e+05],
#        [ 4.63507953e+04],
#        [ 4.85425708e+04],
#        [ 2.71718748e+04],
#        [ 2.92209539e+04],
#        [ 6.76235882e+04],
#        [ 4.78275409e+04],
#        [ 4.10331219e+04],
#        [-2.30788230e+04],
#        [ 6.20127885e+03],
#        [ 4.68125867e+04],
#        [ 6.98280964e+04],
#        [ 6.90008547e+04],
#        [ 4.87915008e+04],
#        [ 7.32348913e+04],
#        [-4.79369729e+03],
#        [ 1.75026173e+04],
#        [ 6.31145393e+04],
#        [ 4.87149198e+04],
#        [ 2.79293316e+04],
#        [ 4.57570681e+04],
#        [ 5.02768138e+04],
#        [ 1.32297657e+04],
#        [ 1.47469821e+04],
#        [ 1.27851091e+04],
#        [ 6.03524658e+03],
#        [ 4.70487840e+04],
#        [ 3.71539325e+04],
#        [ 5.84524746e+04],
#        [ 2.21415663e+04],
#        [ 6.46419486e+04],
#        [ 4.94883872e+04],
#        [ 1.34404748e+05],
#        [ 5.25026221e+04],
#        [ 5.24131928e+04],
#        [ 4.92724628e+04],
#        [ 4.23172372e+04],
#        [ 3.69390353e+04],
#        [ 5.17152978e+04],
#        [ 3.32555724e+04],
#        [ 2.87465235e+04],
#        [ 5.23643279e+04],
#        [ 3.86922758e+04],
#        [ 1.62727235e+04],
#        [ 5.06683466e+04],
#        [ 3.53778515e+02],
#        [ 4.39569189e+04],
#        [ 7.18177074e+04],
#        [ 8.04873043e+02],
#        [ 4.96699528e+03],
#        [ 4.70487840e+04],
#        [ 5.25026221e+04],
#        [ 3.57175780e+04],
#        [ 6.35295016e+04],
#        [ 3.09702023e+04],
#        [ 1.05614303e+04],
#        [ 4.88489331e+04],
#        [ 2.30437553e+04],
#        [ 5.32090846e+04],
#        [ 3.70538999e+04],
#        [ 1.34255850e+05],
#        [ 2.91700531e+04],
#        [ 5.74840657e+04],
#        [ 6.87258423e+04],
#        [ 4.52761060e+04],
#        [ 1.79835793e+04],
#        [-2.70751798e+04],
#        [ 9.72930934e+04],
#        [ 7.45733427e+04],
#        [ 2.37952176e+03],
#        [ 3.24280522e+04],
#        [ 4.81510381e+04],
#        [ 7.04472591e+04],
#        [ 4.30014328e+04],
#        [ 6.47892206e+04],
#        [ 4.49697437e+04],
#        [ 6.36656664e+04],
#        [ 1.55343064e+04],
#        [ 1.65346798e+05],
#        [ 6.32720042e+04],
#        [ 7.56670294e+04],
#        [ 7.99019963e+04],
#        [ 7.17176749e+04],
#        [ 5.46193823e+04],
#        [ 1.25927584e+05],
#        [ 7.76652078e+04],
#        [ 4.12587160e+04],
#        [ 5.36027468e+04],
#        [ 5.68678012e+04],
#        [ 4.55315676e+04],
#        [ 5.31516522e+04],
#        [ 6.43168259e+04],
#        [ 6.42243517e+04],
#        [-2.34442439e+03],
#        [ 3.31066749e+04],
#        [ 6.12041696e+03],
#        [-1.95487296e+01],
#        [ 2.56759585e+04],
#        [ 1.32200240e+05],
#        [ 3.11383640e+04],
#        [ 2.84401611e+04],
#        [ 4.61507302e+04],
#        [ 2.35195689e+03],
#        [ 2.93955536e+04],
#        [ 5.78736800e+03],
#        [ 4.30887326e+04],
#        [ 3.09702023e+04],
#        [-5.35965652e+03],
#        [ 6.36656664e+04],
#        [ 9.99960640e+03],
#        [ 5.15770035e+04],
#        [ 3.02637398e+04],
#        [ 1.58541754e+05],
#        [ 5.54561930e+04],
#        [ 3.86137165e+04],
#        [ 4.18204463e+04],
#        [ 5.34091496e+04],
#        [ 4.95216910e+04],
#        [ 1.37533279e+04],
#        [ 4.54741353e+04],
#        [-1.43416521e+04],
#        [ 6.13321375e+04],
#        [-2.88813660e+02],
#        [ 5.69308092e+04],
#        [ 1.67651339e+05],
#        [ 3.48792592e+04],
#        [ 3.92601682e+04],
#        [ 4.41143838e+04],
#        [ 4.51379054e+04],
#        [ 7.89908329e+04],
#        [ 5.31202781e+04],
#        [ 4.91552955e+04],
#        [ 6.22293119e+04],
#        [ 3.78240895e+04],
#        [ 5.44815363e+04],
#        [ 5.08471115e+04],
#        [ 3.19067139e+04],
#        [ 3.94478700e+04],
#        [ 1.08677926e+04],
#        [-7.43446785e+03],
#        [ 9.46757523e+04],
#        [ 1.94134959e+04],
#        [ 2.32628178e+04],
#        [ 1.01782972e+05],
#        [ 3.43684297e+04],
#        [ 3.86462163e+04],
#        [ 1.67451605e+04],
#        [ 3.83700229e+04],
#        [ 1.75603925e+04],
#        [ 2.48673340e+04],
#        [ 1.08677926e+04],
#        [ 4.76651122e+04],
#        [ 5.24217602e+04],
#        [ 5.38218093e+04],
#        [ 5.70711392e+04],
#        [ 1.91071335e+04],
#        [-7.69775672e+02],
#        [ 1.38767029e+05],
#        [ 7.26050318e+04],
#        [ 5.93928148e+04],
#        [ 1.05614303e+04],
#        [ 6.25442416e+04],
#        [ 5.66276893e+04],
#        [ 6.20127885e+03],
#        [ 4.99042483e+03],
#        [ 6.18178161e+04],
#        [-2.44087070e+04],
#        [ 3.76923268e+04],
#        [ 1.39103259e+05],
#        [-3.49525886e+04],
#        [ 4.50591730e+04],
#        [ 2.61865212e+04],
#        [-2.51902406e+03],
#        [ 1.65779827e+05],
#        [ 1.94134959e+04],
#        [ 5.05015980e+03],
#        [ 3.12765647e+04],
#        [ 4.76978141e+04],
#        [ 5.62136498e+04],
#        [ 3.70560294e+04],
#        [ 4.51379054e+04],
#        [ 5.45496655e+04],
#        [ 5.36836087e+04],
#        [ 5.08471115e+04],
#        [ 9.47489262e+04],
#        [ 4.55549035e+04],
#        [ 2.03582851e+04],
#        [ 8.15065777e+04],
#        [ 8.81983925e+04],
#        [ 6.12844403e+04],
#        [ 6.25048754e+04],
#        [ 2.32692558e+04],
#        [ 1.39967186e+05],
#        [ 5.41395449e+03],
#        [ 5.25300934e+04],
#        [ 5.82905607e+04],
#        [ 5.38398889e+04],
#        [ 3.63871042e+04],
#        [ 4.30887326e+04],
#        [ 6.94344343e+04],
#        [ 3.09595991e+04],
#        [ 5.83501225e+04],
#        [ 2.50928345e+04],
#        [ 2.01433879e+04],
#        [ 3.49302536e+04],
#        [-9.73900857e+03],
#        [ 1.65346798e+05],
#        [ 3.04892403e+04],
#        [ 5.03278325e+04],
#        [ 4.76732072e+04],
#        [-1.99402224e+04],
#        [ 3.62494408e+04],
#        [ 3.83050515e+04],
#        [ 4.54507057e+04],
#        [ 4.39569189e+04],
#        [ 2.48099017e+04],
#        [ 4.38186246e+04],
#        [ 1.82026419e+04],
#        [ 1.43535895e+05],
#        [ 2.06817823e+04],
#        [ 5.70308417e+04],
#        [ 7.96335187e+04],
#        [ 5.59072875e+04],
#        [ 4.92724628e+04],
#        [ 1.80836119e+04],
#        [ 3.14131709e+03],
#        [ 1.34786957e+04],
#        [ 7.02430587e+04],
#        [ 1.78257208e+04],
#        [ 5.89118527e+04],
#        [ 2.83850484e+04],
#        [ 6.90008547e+04],
#        [ 4.79935732e+04],
#        [ 1.42565356e+05],
#        [-9.47209216e+03],
#        [ 3.87285812e+04],
#        [ 5.81139252e+04],
#        [ 6.09674635e+04],
#        [ 2.37952176e+03],
#        [ 6.42167934e+04],
#        [ 5.55710577e+04],
#        [ 3.73795265e+04],
#        [ 1.79647259e+04],
#        [ 1.36532954e+04],
#        [ 1.42801554e+05],
#        [ 4.76786435e+04],
#        [ 1.53476505e+03],
#        [ 6.76235882e+04],
#        [ 1.63216308e+04],
#        [ 1.37428577e+05],
#        [ 6.87292278e+04],
#        [ 1.75822967e+03],
#        [ 5.48071629e+04],
#        [ 7.49670049e+04],
#        [ 2.62845175e+03],
#        [ 6.56731073e+04],
#        [ 4.24929059e+04],
#        [ 3.55792838e+04],
#        [ 1.52134581e+05],
#        [ 4.58677974e+04],
#        [ 4.87915008e+04],
#        [ 7.76651141e+04],
#        [ 5.42347357e+04]])

# %% [markdown]
# *   Se calculan las medidas de error para conocer si el modelo logra predecir los valores de las vehículos en el conjunto de prueba

# %%
MAE = metrics.mean_absolute_error(Y_test, predicciones)
RMSE=np.sqrt(mean_squared_error(Y_test, predicciones))
coeficiente= r2_score(Y_test, predicciones)
MAPE=mean_absolute_percentage_error(Y_test, predicciones)

print("MAE = ",MAE)
print("RMSE = ",RMSE)
print("Coeficiente de determinación = ",coeficiente)
print("MAPE (Mean absolute percentage error) = ",MAPE)
# Out:
# MAE =  23883.202241754305
# RMSE =  44603.46799950041
# Coeficiente de determinación =  0.4383595874697205
# MAPE (Mean absolute percentage error) =  0.6865281380534184

# %% [markdown]
# # **Validación cruzada.** La validación cruzada es una técnica que permite evaluar modelos de machine learning usando diferentes subconjuntos de los datos para entrenar para luego evaluarlos con el subconjunto complementario.

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# # Validación cruzada con k=5

# %%
from sklearn.model_selection import cross_val_score

modelo2=LinearRegression()
validacion2=cross_val_score(modelo2, X, Y, cv=5, scoring="neg_mean_absolute_error")
print(validacion2)
# Out:
# [-24408.59822334 -24308.64613588 -23444.77273939 -22096.2207402
#  -22972.78749143]

# %% [markdown]
# *   Se puede obtener el promedio y la desviación

# %%
print("El modelo 2 tiene un MAE promedio de %f con una desviación estándar de %f" % (validacion2.mean(), validacion2.std()))
# Out:
# El modelo 2 tiene un MAE promedio de -23446.205066 con una desviación estándar de 862.158816

# %% [markdown]
# # Validación cruzada con k=10

# %%
from sklearn.model_selection import cross_val_score
modelo3=LinearRegression()
validacion3=cross_val_score(modelo3, X, Y, cv=10, scoring="neg_mean_absolute_error")
print(validacion3)
# Out:
# [-21533.38305338 -27455.75646602 -28080.99638787 -20820.33566708
#  -21221.99599317 -25723.61268867 -21731.55500125 -21883.5541165
#  -25249.60038186 -20462.39327606]

# %%
print("El modelo 3 tiene un MAE promedio de %f con una desviación estándar de %f" % (validacion3.mean(), validacion3.std()))
# Out:
# El modelo 3 tiene un MAE promedio de -23416.318303 con una desviación estándar de 2752.705955
